# %%
! pip install json
# Out:
# ERROR: Could not find a version that satisfies the requirement json (from versions: none)
# ERROR: No matching distribution found for json

# %%
import json

# %%
with open('episodes.json', 'r') as f:
    episodes = json.load(f)

# %%
episodes[0]
# Out:
# {'episode_id': 'hotpot_oberoi_001',
#  'conversation_domain': 'general_knowledge',
#  'difficulty': 'medium',
#  'messages': [{'id': 0,
#    'text': 'The Ritz-Carlton Jakarta is a hotel and skyscraper in Jakarta, Indonesia.',
#    'isRelevant': False,
#    'fact_id': None},
#   {'id': 1,
#    'text': 'The Oberoi family is an Indian family that is famous for its involvement in hotels.',
#    'isRelevant': True,
#    'fact_id': 0},
#   {'id': 2,
#    'text': 'The Hotel Tallcorn is located in Marshalltown, Iowa.',
#    'isRelevant': False,
#    'fact_id': None},
#   {'id': 3,
#    'text': 'The Oberoi Group is a hotel company with its head office in Delhi.',
#    'isRelevant': True,
#    'fact_id': 1},
#   {'id': 4,
#    'text': 'Future Fibre Technologies is a fiber optic sensing company based in Melbourne.',
#    'isRelevant': False,
#    'fact_id': None},
#   {'id': 5,
#    'text': 'Rai Bahadur Mohan Singh Oberoi was the founder of Oberoi Hotels & Resorts.',
#    'isRelevant': False,
#    'fact_id': None},
#   {'id': 6,
#    'text': 'The 289th Military Police Company was activated in 1994.',
#    'isRelevant': False,
#    'fact_id': None},
#   {'id': 7,
#    'text': 'The Oberoi Group owns and operates luxury hotels across multiple countries.',
#    'isRelevant': False,
#    'fact_id': None},
#   {'id': 8,
#    'text': 'Ishqbaaaz is an Indian television drama series broadcast on Star Plus.',
#    'isRelevant': False,
#    'fact_id': None},
#   {'id': 9,
#    'text': 'The Glennwanis Hotel is located in Glennville, Georgia.',
#    'isRelevant': False,
#    'fact_id': None}],
#  'key_facts': [{'id': 0, 'text': 'Oberoi family is involved in hotels'},
#   {'id': 1, 'text': 'Oberoi Group head office is in Delhi'}],
#  'questions': [{'question': 'The Oberoi family is part of a hotel company that has a head office in what city?',
#    'answer': 'Delhi',
#    'supporting_fact_ids': [0, 1]}]}

# %%
episodes[0].get()

# %%
with open('episodes.json', 'r') as f:
        episodes = json.load(f)

# %%
# Out:
# {'text': 'I have been trying to build an AI system that can automatically generate multiple-choice questions from lecture notes, but I am struggling with ensuring the questions are actually meaningful and not just surface-level pattern matches.',
#  'isRelevant': True}
